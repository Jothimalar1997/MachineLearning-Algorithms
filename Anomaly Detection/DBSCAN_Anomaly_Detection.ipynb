# %%
from sklearn.cluster import DBSCAN
## from sklearn.datasets import make_moons - Non linearly separable data
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles   ## Linearly separable data

# %%
X, y = make_circles(n_samples=750, factor=0.3, noise=0.1)

# %%
plt.scatter(X[:,0],X[:,1])

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
from sklearn.cluster import DBSCAN
dbscan=DBSCAN(eps=0.1)
dbscan.fit_predict(X)
# Out:
# array([ 0,  1,  0,  1,  0,  4, 13,  2,  0,  0,  3,  4,  2,  5,  0,  0,  4,
#         0,  0,  1,  1,  1, 10,  0,  6, -1,  0,  3,  0,  5,  0,  0,  0,  0,
#         0,  4,  0,  0,  0,  0,  0,  0,  6, -1,  0,  1,  4,  0,  0,  1, -1,
#         7,  0,  0,  0, -1,  1,  0,  7,  8,  2,  0,  0,  3,  0,  0,  1,  0,
#         9,  0,  0,  1,  0,  0,  8,  0,  0,  0,  4,  0, 10,  5,  1,  1,  0,
#         0,  0,  0,  0,  0,  6, -1,  9,  3,  4, -1,  0,  0,  0,  5,  3,  2,
#         0,  0,  2,  0,  0, -1,  0,  1,  1,  0,  1,  0,  5,  0,  0,  0,  9,
#         0,  4,  0,  0,  3,  1,  0,  0, -1,  1,  9,  4,  0, -1,  3,  2,  0,
#         0,  0,  0, 10,  0,  0,  9,  0,  0,  0,  0,  0,  3,  9,  0,  0,  0,
#         3,  0,  0,  0,  0, 11,  0,  0,  0,  0,  0,  0,  4,  0,  5, -1,  3,
#         0,  9,  5, -1,  6,  3,  0,  4,  6,  4,  1,  0,  3,  0,  0, -1,  0,
#         7,  1, -1,  2,  0,  4,  0,  4,  0,  5,  0,  0,  0,  5,  5,  0,  0,
#         0,  0,  0,  1,  4, 10,  0,  1,  0,  0, -1,  0, 11,  6, -1,  0,  0,
#         4,  0,  0,  0, -1,  3,  0, -1,  3,  0,  9,  5,  0,  0,  0,  0,  3,
#         6, -1,  0,  0,  4, 11,  1, 11, -1,  2,  0,  0,  0,  1,  2,  0,  0,
#         4, -1, 12,  0, 10, 12,  0,  3,  0,  7,  4,  0,  0,  0,  5,  0,  0,
#         4,  6, 11,  0,  2,  0,  0,  0,  3,  1, 11, 13,  0,  0,  4,  0,  7,
#         0,  1, 11,  0,  0,  9, -1,  0,  0,  1, -1,  9,  1,  1,  4,  5,  3,
#         2,  1, -1, 11,  0,  0,  0,  0, -1,  2,  0, 11,  0,  0,  1,  0,  6,
#         2,  0,  4,  0,  7,  0,  0,  1,  7,  0,  7,  0,  0,  0,  0,  1, -1,
#         2,  0,  9,  0,  0,  0,  0,  0,  0,  3,  0, 11,  0,  0, 11,  0,  3,
#         0, -1,  6,  0,  0, 10,  7, 11,  1,  0,  2,  0,  0,  4,  9,  0,  1,
#         0, 12,  1,  0, 11,  9, -1,  0, -1, -1,  4,  3,  0,  4,  0,  1, 11,
#         0,  0,  0,  0,  4,  2, 13,  0,  4,  0,  6,  4,  0,  0,  8,  4,  3,
#         1,  0,  1, 11, 13,  0,  0,  5,  0, -1,  0,  5,  2,  9,  0,  2,  3,
#         0,  7,  0,  0,  0,  7,  9, 13,  1,  0,  0,  0,  0,  0,  5,  0,  6,
#         7,  8,  0,  0, 11, -1,  0,  0,  0,  4, -1, -1,  0,  1,  0,  0,  0,
#         0,  5,  0,  5,  0,  1,  0,  0,  0,  0,  9, 10,  3,  0,  0,  0,  2,
#         0,  5,  9,  2,  1,  0, 10,  8,  7,  4,  0, 10,  0, 13, 10, 10, 10,
#         0,  0,  0,  5,  0,  4, 10,  0,  0,  9,  0,  0,  0, 11,  3,  0,  2,
#         0,  0,  0, 11,  0,  0,  6,  2, -1, -1, 13,  7,  0,  2,  0,  2,  0,
#         0, -1, -1,  3,  7,  0,  0,  0,  0,  0,  9,  1,  3,  0,  0,  3,  0,
#         0,  0,  7,  0,  0,  0,  0,  7,  1,  0, 12,  0,  5,  0,  0,  0, 10,
#         9,  0,  9,  4, 10,  5,  8,  0,  0,  5, 11,  0,  7,  0,  0, -1,  1,
#         7,  0,  0,  0,  0,  0,  0,  8,  0,  0,  0,  0, -1,  4,  9, 11,  0,
#        -1,  1,  0,  1,  0,  2,  0,  3,  1,  3,  2,  0,  0, -1, 11,  0,  0,
#         0,  9,  0,  6,  0,  0,  5,  4,  0,  1,  0,  0,  0,  0,  0,  9,  0,
#         8,  0,  0, -1,  0,  0,  7,  0, 11,  3,  0,  0,  5,  1, 13,  0,  2,
#         0,  9,  0,  1,  0,  1,  1,  0,  1,  0,  5,  0, 10,  0,  0,  8,  0,
#         0, 13,  0,  0,  3,  0, -1,  0, -1,  0,  0,  6,  0,  0,  1,  2,  4,
#         8,  0,  0,  6,  0,  9,  0,  0,  0,  0,  0, 13,  0,  0,  7,  0,  9,
#         0,  7,  2,  5,  0,  0,  6,  0,  8,  3,  1, 11, 12,  0,  6,  0,  0,
#         0,  4,  5,  8,  7,  0,  9,  8,  3,  0,  8,  8,  0,  0,  6,  0,  2,
#         0,  0,  6,  3,  2, -1,  0,  0,  7,  6,  0,  9, -1,  0,  4,  5,  0,
#         0,  0])

# %%
dbscan.labels_
# Out:
# array([ 0,  1,  0,  1,  0,  4, 13,  2,  0,  0,  3,  4,  2,  5,  0,  0,  4,
#         0,  0,  1,  1,  1, 10,  0,  6, -1,  0,  3,  0,  5,  0,  0,  0,  0,
#         0,  4,  0,  0,  0,  0,  0,  0,  6, -1,  0,  1,  4,  0,  0,  1, -1,
#         7,  0,  0,  0, -1,  1,  0,  7,  8,  2,  0,  0,  3,  0,  0,  1,  0,
#         9,  0,  0,  1,  0,  0,  8,  0,  0,  0,  4,  0, 10,  5,  1,  1,  0,
#         0,  0,  0,  0,  0,  6, -1,  9,  3,  4, -1,  0,  0,  0,  5,  3,  2,
#         0,  0,  2,  0,  0, -1,  0,  1,  1,  0,  1,  0,  5,  0,  0,  0,  9,
#         0,  4,  0,  0,  3,  1,  0,  0, -1,  1,  9,  4,  0, -1,  3,  2,  0,
#         0,  0,  0, 10,  0,  0,  9,  0,  0,  0,  0,  0,  3,  9,  0,  0,  0,
#         3,  0,  0,  0,  0, 11,  0,  0,  0,  0,  0,  0,  4,  0,  5, -1,  3,
#         0,  9,  5, -1,  6,  3,  0,  4,  6,  4,  1,  0,  3,  0,  0, -1,  0,
#         7,  1, -1,  2,  0,  4,  0,  4,  0,  5,  0,  0,  0,  5,  5,  0,  0,
#         0,  0,  0,  1,  4, 10,  0,  1,  0,  0, -1,  0, 11,  6, -1,  0,  0,
#         4,  0,  0,  0, -1,  3,  0, -1,  3,  0,  9,  5,  0,  0,  0,  0,  3,
#         6, -1,  0,  0,  4, 11,  1, 11, -1,  2,  0,  0,  0,  1,  2,  0,  0,
#         4, -1, 12,  0, 10, 12,  0,  3,  0,  7,  4,  0,  0,  0,  5,  0,  0,
#         4,  6, 11,  0,  2,  0,  0,  0,  3,  1, 11, 13,  0,  0,  4,  0,  7,
#         0,  1, 11,  0,  0,  9, -1,  0,  0,  1, -1,  9,  1,  1,  4,  5,  3,
#         2,  1, -1, 11,  0,  0,  0,  0, -1,  2,  0, 11,  0,  0,  1,  0,  6,
#         2,  0,  4,  0,  7,  0,  0,  1,  7,  0,  7,  0,  0,  0,  0,  1, -1,
#         2,  0,  9,  0,  0,  0,  0,  0,  0,  3,  0, 11,  0,  0, 11,  0,  3,
#         0, -1,  6,  0,  0, 10,  7, 11,  1,  0,  2,  0,  0,  4,  9,  0,  1,
#         0, 12,  1,  0, 11,  9, -1,  0, -1, -1,  4,  3,  0,  4,  0,  1, 11,
#         0,  0,  0,  0,  4,  2, 13,  0,  4,  0,  6,  4,  0,  0,  8,  4,  3,
#         1,  0,  1, 11, 13,  0,  0,  5,  0, -1,  0,  5,  2,  9,  0,  2,  3,
#         0,  7,  0,  0,  0,  7,  9, 13,  1,  0,  0,  0,  0,  0,  5,  0,  6,
#         7,  8,  0,  0, 11, -1,  0,  0,  0,  4, -1, -1,  0,  1,  0,  0,  0,
#         0,  5,  0,  5,  0,  1,  0,  0,  0,  0,  9, 10,  3,  0,  0,  0,  2,
#         0,  5,  9,  2,  1,  0, 10,  8,  7,  4,  0, 10,  0, 13, 10, 10, 10,
#         0,  0,  0,  5,  0,  4, 10,  0,  0,  9,  0,  0,  0, 11,  3,  0,  2,
#         0,  0,  0, 11,  0,  0,  6,  2, -1, -1, 13,  7,  0,  2,  0,  2,  0,
#         0, -1, -1,  3,  7,  0,  0,  0,  0,  0,  9,  1,  3,  0,  0,  3,  0,
#         0,  0,  7,  0,  0,  0,  0,  7,  1,  0, 12,  0,  5,  0,  0,  0, 10,
#         9,  0,  9,  4, 10,  5,  8,  0,  0,  5, 11,  0,  7,  0,  0, -1,  1,
#         7,  0,  0,  0,  0,  0,  0,  8,  0,  0,  0,  0, -1,  4,  9, 11,  0,
#        -1,  1,  0,  1,  0,  2,  0,  3,  1,  3,  2,  0,  0, -1, 11,  0,  0,
#         0,  9,  0,  6,  0,  0,  5,  4,  0,  1,  0,  0,  0,  0,  0,  9,  0,
#         8,  0,  0, -1,  0,  0,  7,  0, 11,  3,  0,  0,  5,  1, 13,  0,  2,
#         0,  9,  0,  1,  0,  1,  1,  0,  1,  0,  5,  0, 10,  0,  0,  8,  0,
#         0, 13,  0,  0,  3,  0, -1,  0, -1,  0,  0,  6,  0,  0,  1,  2,  4,
#         8,  0,  0,  6,  0,  9,  0,  0,  0,  0,  0, 13,  0,  0,  7,  0,  9,
#         0,  7,  2,  5,  0,  0,  6,  0,  8,  3,  1, 11, 12,  0,  6,  0,  0,
#         0,  4,  5,  8,  7,  0,  9,  8,  3,  0,  8,  8,  0,  0,  6,  0,  2,
#         0,  0,  6,  3,  2, -1,  0,  0,  7,  6,  0,  9, -1,  0,  4,  5,  0,
#         0,  0])

# %%
plt.scatter(X[:,0],X[:,1],c=dbscan.labels_)
